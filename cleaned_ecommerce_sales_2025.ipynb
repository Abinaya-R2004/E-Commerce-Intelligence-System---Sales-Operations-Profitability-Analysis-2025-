# %% [markdown]
# #Basic Data Cleaning Steps

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('default')

# %%
df=pd.read_csv(r"C:\Users\abina\Downloads\synthetic_ecommerce_sales_2025\synthetic_ecommerce_sales_2025.csv")

# %%
df.head()
# Out:
#    order_id                           customer_id product_category  \
# 0         1  bdd640fb-0667-4ad1-9c80-317fa3b1799d           Beauty
# 1         2  23b8c1e9-3924-46de-beb1-3b9046685257          Fashion
# 2         3  bd9c66b3-ad3c-4d6d-9a3d-1fa7bc8960a9           Beauty
# 3         4  972a8469-1641-4f82-8b9d-2434e465e150      Electronics
# 4         5  17fc695a-07a0-4a6e-8822-e8f36c031199          Fashion
#
#    product_price  quantity  order_date         region payment_method  \
# 0         190.40         5  2023-02-21         Europe   BankTransfer
# 1          82.22         3  2023-10-13  North America     CreditCard
# 2          15.19         2  2023-06-28        Oceania           Cash
# 3         310.65         2  2023-07-11         Europe         PayPal
# 4          74.05         4  2023-02-24         Africa         PayPal
#
#    delivery_days  is_returned  customer_rating  discount_percent  revenue
# 0              8            0              3.8                 0   952.00
# 1              5            0              3.8                 0   246.66
# 2              6            1              2.0                10    27.34
# 3              9            0              2.9                 5   590.23
# 4              3            1              3.1                20   236.96

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   order_id          100000 non-null  int64
#  1   customer_id       100000 non-null  object
#  2   product_category  100000 non-null  object
#  3   product_price     100000 non-null  float64
#  4   quantity          100000 non-null  int64
#  5   order_date        100000 non-null  object
#  6   region            100000 non-null  object
#  7   payment_method    100000 non-null  object
#  8   delivery_days     100000 non-null  int64
#  9   is_returned       100000 non-null  int64
#  10  customer_rating   100000 non-null  float64
#  11  discount_percent  100000 non-null  int64
#  12  revenue           100000 non-null  float64
# dtypes: float64(3), int64(5), object(5)
# memory usage: 9.9+ MB

# %%
df.shape
# Out:
# (100000, 13)

# %%
df.isnull().sum()
# Out:
# order_id            0
# customer_id         0
# product_category    0
# product_price       0
# quantity            0
# order_date          0
# region              0
# payment_method      0
# delivery_days       0
# is_returned         0
# customer_rating     0
# discount_percent    0
# revenue             0
# dtype: int64

# %% [markdown]
# #Basic cleaning

# %%
#standardizing column names
df.columns=df.columns.str.lower().str.replace(' ','_')
df.columns
# Out:
# Index(['order_id', 'customer_id', 'product_category', 'product_price',
#        'quantity', 'order_date', 'region', 'payment_method', 'delivery_days',
#        'is_returned', 'customer_rating', 'discount_percent', 'revenue'],
#       dtype='object')

# %%
#Filling missing discounts
if 'discount' in df.columns:
    df['discount'] = df['discount'].fillna(0)

# %%
#date conversion
df['order_date']=pd.to_datetime(df['order_date'])

# %%
#numeric_columns_conversion
num_cols = ['product_price','quantity','delivery_days','customer_rating','discount_percent','revenue']
df[num_cols] = df[num_cols].apply(pd.to_numeric,errors='coerce')

# %%
#Removing invalid transactions
df = df[
    (df['product_price']>0) &
    (df['quantity']>0)&
    (df['revenue']>0)]

# %%
#validating discount logic
df = df[(df['discount_percent']>=0) & (df['discount_percent']<=100)]

# %%
#Remove duplicates(if any)
df = df.drop_duplicates()

# %% [markdown]
# # Removed exact duplicate transactional records to avoid KPI inflation

# %%
#Standardizing categorical values
df['product_category'] = df['product_category'].str.title()

# %%
df['payment_method'] = df['payment_method'].str.replace(' ','').str.title()

# %%
df['region'] = df['region'].str.title()

# %%
#Derived Business columns
df['order_value'] = df['product_price'] * df['quantity']

df['net_order_value'] = df['order_value'] * (
    1-df['discount_percent']/100
)

# %%
#Final column order
cleaned_df = df[[
    'order_id',
    'order_date',
    'customer_id',
    'product_category',
    'region',
    'payment_method',
    'product_price',
    'quantity',
    'discount_percent',
    'order_value',
    'net_order_value',
    'delivery_days',
    'customer_rating',
    'is_returned'
]]

# %%
cleaned_df
# Out:
#        order_id order_date                           customer_id  \
# 0             1 2023-02-21  bdd640fb-0667-4ad1-9c80-317fa3b1799d
# 1             2 2023-10-13  23b8c1e9-3924-46de-beb1-3b9046685257
# 2             3 2023-06-28  bd9c66b3-ad3c-4d6d-9a3d-1fa7bc8960a9
# 3             4 2023-07-11  972a8469-1641-4f82-8b9d-2434e465e150
# 4             5 2023-02-24  17fc695a-07a0-4a6e-8822-e8f36c031199
# ...         ...        ...                                   ...
# 99995     99996 2025-07-21  95898eb0-3712-4824-accb-8d40fab73167
# 99996     99997 2023-02-09  960dc639-d199-4aae-a22e-18d4dfc07403
# 99997     99998 2023-06-13  f9897ea5-454f-43c2-a464-2de35502fe95
# 99998     99999 2024-10-15  17d6608f-5c4b-44da-a4ec-f3171120f7bb
# 99999    100000 2025-03-01  e6f4e3ae-a886-4da4-acbf-992019070b38
#
#       product_category         region payment_method  product_price  quantity  \
# 0               Beauty         Europe   Banktransfer         190.40         5
# 1              Fashion  North America     Creditcard          82.22         3
# 2               Beauty        Oceania           Cash          15.19         2
# 3          Electronics         Europe         Paypal         310.65         2
# 4              Fashion         Africa         Paypal          74.05         4
# ...                ...            ...            ...            ...       ...
# 99995           Beauty         Europe         Paypal         354.84         5
# 99996       Automotive  North America           Cash         168.49         2
# 99997      Electronics           Asia         Paypal         266.82         3
# 99998          Fashion  North America   Banktransfer          36.09         1
# 99999             Toys           Asia   Banktransfer         174.20         2
#
#        discount_percent  order_value  net_order_value  delivery_days  \
# 0                     0       952.00         952.0000              8
# 1                     0       246.66         246.6600              5
# 2                    10        30.38          27.3420              6
# 3                     5       621.30         590.2350              9
# 4                    20       296.20         236.9600              3
# ...                 ...          ...              ...            ...
# 99995                 0      1774.20        1774.2000              8
# 99996                 0       336.98         336.9800              7
# 99997                 0       800.46         800.4600              5
# 99998                 5        36.09          34.2855              6
# 99999                 5       348.40         330.9800              9
#
#        customer_rating  is_returned
# 0                  3.8            0
# 1                  3.8            0
# 2                  2.0            1
# 3                  2.9            0
# 4                  3.1            1
# ...                ...          ...
# 99995              3.0            0
# 99996              4.5            0
# 99997              3.6            0
# 99998              3.3            1
# 99999              3.4            0
#
# [100000 rows x 14 columns]

# %%
cleaned_df.to_csv("cleaned_ecommerce_sales_2025.csv",index=False)
